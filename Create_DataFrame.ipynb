# %% [markdown]
# <a href="https://colab.research.google.com/github/fazekas-gergo/composer-ai/blob/master/Create_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Create DataFrame
# Create and save DataFrame from the following dataset: https://www.kaggle.com/soumikrakshit/classical-music-midi

# %% [markdown]
# ---
# Download necessary files and install packages.

# %%
# !git clone -l -s https://github.com/fazekas-gergo/composer-ai composer-ai
# %cd composer-ai
# !pip install pretty_midi
# Out:
# Cloning into 'composer-ai'...
# warning: --local is ignored
# remote: Enumerating objects: 420, done.
# remote: Counting objects: 100% (420/420), done.
# remote: Compressing objects: 100% (412/412), done.
# remote: Total 420 (delta 42), reused 348 (delta 5), pack-reused 0
# Receiving objects: 100% (420/420), 160.79 MiB | 14.10 MiB/s, done.
# Resolving deltas: 100% (42/42), done.
# /content/composer-ai
# Collecting pretty_midi
#   Downloading pretty_midi-0.2.9.tar.gz (5.6 MB)
#      |████████████████████████████████| 5.6 MB 5.3 MB/s
# Requirement already satisfied: numpy>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from pretty_midi) (1.21.5)
# Collecting mido>=1.1.16
#   Downloading mido-1.2.10-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 6.6 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from pretty_midi) (1.15.0)
# Building wheels for collected packages: pretty-midi
#   Building wheel for pretty-midi (setup.py) ... done
#   Created wheel for pretty-midi: filename=pretty_midi-0.2.9-py3-none-any.whl size=5591955 sha256=3c4efc8f3824c0d4692a8451e51a0093a40ee26b11b51f809331db7ef7915f53
#   Stored in directory: /root/.cache/pip/wheels/ad/74/7c/a06473ca8dcb63efb98c1e67667ce39d52100f837835ea18fa
# Successfully built pretty-midi
# Installing collected packages: mido, pretty-midi
# Successfully installed mido-1.2.10 pretty-midi-0.2.9

# %%
import os
import pretty_midi
import pandas as pd

# %% [markdown]
# Create a list of the midi files.

# %%
def get_midi_file_paths(main_folder):
  files = []
  for dir in os.listdir(main_folder):
    for file in os.listdir(main_folder + os.path.sep + dir):
      files.append(main_folder + os.path.sep + dir + os.path.sep + file)
  return files

midi_file_paths = get_midi_file_paths('classical_music_midi')
print('Number of read MIDI files:', len(midi_file_paths))
# Out:
# Number of read MIDI files: 295

# %% [markdown]
# The following block creates one pandas dataframe from the midi files.<br>
# Only the  *piano left* and *piano right* instruments are used. In case of the midi file does not contain these instruments, then that file is ignored .<br>
# <br>
# The alorighm groups the notes by their start to handle them together.<br>
# Indexes:
#
# *   name of the piano piece
# *   number index of the note

# %%
from pretty_midi.instrument import Instrument

def midi_files_to_df(paths):
  data_frames = [midi_file_to_df(file_path) for file_path in paths]
  names = list(map(lambda p: p.replace("classical_music_midi/", ""), paths))
  return pd.concat(data_frames, keys=names)

def midi_file_to_df(midi_file_name: str):
  m = pretty_midi.PrettyMIDI(midi_file_name)
  piano_left = list(filter(lambda inst: inst.name.lower() == 'piano left', m.instruments))
  piano_right = list(filter(lambda inst: inst.name.lower() == 'piano right', m.instruments))
  if len(piano_left) == 1 and len(piano_right) == 1:
    print('use file:', midi_file_name)
    return __piano_to_df(piano_left[0], piano_right[0])
  else:
    print('ignore file:', midi_file_name)

def __piano_to_df(piano_left: Instrument, piano_right: Instrument):
  piano_notes_df = __create_df_from_piano_notes(piano_left, piano_right)
  return __group_notes(piano_notes_df)
  

def __create_df_from_piano_notes(piano_left: Instrument, piano_right: Instrument):
  piano_left_df = __create_df_from_instrument_notes(piano_left)
  piano_right_df = __create_df_from_instrument_notes(piano_right)
  return pd.concat([piano_left_df, piano_right_df]).sort_values(['start']).reset_index()

def __create_df_from_instrument_notes(instrument: Instrument):
  return pd.DataFrame([{
        'start': n.start, 
        'end': n.end, 
        'pitch': n.pitch, 
        'velocity': n.velocity
    } for n in instrument.notes])

def __group_notes(df: pd.DataFrame):
  dataset = []
  for start, note_df in df.groupby(['start'], sort=True):
    pitches = __create_pitch_arr(note_df)
    velocity = note_df['velocity'].mean()
    dataset.append([pitches, velocity, start])
  new_df = pd.DataFrame(dataset, columns=['pitches', 'velocity', 'start'])
  new_df['duration'] = new_df['start'].diff(periods=-1)*(-1)
  return new_df.drop(['start'], axis=1).iloc[:-1]

def __create_pitch_arr(note_df):
  return [int(d['pitch']) for _, d in note_df.sort_values(['pitch']).iterrows()]

dataset = midi_files_to_df(midi_file_paths)
# Out:
# use file: classical_music_midi/haydn/haydn_9_3.mid
# use file: classical_music_midi/haydn/haydn_8_2.mid
# use file: classical_music_midi/haydn/haydn_9_2.mid
# use file: classical_music_midi/haydn/haydn_35_1.mid
# use file: classical_music_midi/haydn/haydn_35_2.mid
# use file: classical_music_midi/haydn/haydn_43_3.mid
# use file: classical_music_midi/haydn/haydn_9_1.mid
# use file: classical_music_midi/haydn/haydn_8_4.mid
# use file: classical_music_midi/haydn/haydn_7_3.mid
# use file: classical_music_midi/haydn/haydn_33_1.mid
# use file: classical_music_midi/haydn/haydn_43_1.mid
# use file: classical_music_midi/haydn/haydn_43_2.mid
# use file: classical_music_midi/haydn/hay_40_2.mid
# use file: classical_music_midi/haydn/haydn_8_3.mid
# use file: classical_music_midi/haydn/haydn_33_2.mid
# use file: classical_music_midi/haydn/hay_40_1.mid
# use file: classical_music_midi/haydn/haydn_35_3.mid
# use file: classical_music_midi/haydn/haydn_7_1.mid
# use file: classical_music_midi/haydn/haydn_33_3.mid
# use file: classical_music_midi/haydn/haydn_7_2.mid
# use file: classical_music_midi/haydn/haydn_8_1.mid
# use file: classical_music_midi/tschai/ty_februar.mid
# use file: classical_music_midi/tschai/ty_oktober.mid
# use file: classical_music_midi/tschai/ty_august.mid
# use file: classical_music_midi/tschai/ty_november.mid
# use file: classical_music_midi/tschai/ty_juli.mid
# use file: classical_music_midi/tschai/ty_april.mid
# use file: classical_music_midi/tschai/ty_september.mid
# use file: classical_music_midi/tschai/ty_maerz.mid
# use file: classical_music_midi/tschai/ty_juni.mid
# use file: classical_music_midi/tschai/ty_dezember.mid
# use file: classical_music_midi/tschai/ty_januar.mid
# use file: classical_music_midi/tschai/ty_mai.mid
# use file: classical_music_midi/schumann/scn16_7.mid
# use file: classical_music_midi/schumann/scn16_2.mid
# use file: classical_music_midi/schumann/scn16_5.mid
# use file: classical_music_midi/schumann/scn15_8.mid
# use file: classical_music_midi/schumann/scn15_11.mid
# use file: classical_music_midi/schumann/scn15_3.mid
# use file: classical_music_midi/schumann/scn15_9.mid
# use file: classical_music_midi/schumann/scn15_4.mid
# use file: classical_music_midi/schumann/scn15_2.mid
# use file: classical_music_midi/schumann/schum_abegg.mid
# use file: classical_music_midi/schumann/scn15_5.mid
# use file: classical_music_midi/schumann/scn16_1.mid
# use file: classical_music_midi/schumann/scn16_3.mid
# use file: classical_music_midi/schumann/scn15_13.mid
# use file: classical_music_midi/schumann/scn15_6.mid
# use file: classical_music_midi/schumann/scn16_6.mid
# use file: classical_music_midi/schumann/scn16_4.mid
# use file: classical_music_midi/schumann/scn68_10.mid
# use file: classical_music_midi/schumann/scn15_1.mid
# use file: classical_music_midi/schumann/scn15_12.mid
# use file: classical_music_midi/schumann/scn15_10.mid
# use file: classical_music_midi/schumann/scn16_8.mid
# use file: classical_music_midi/schumann/scn15_7.mid
# use file: classical_music_midi/schumann/scn68_12.mid
# use file: classical_music_midi/chopin/chpn_op25_e1.mid
# use file: classical_music_midi/chopin/chpn_op25_e4.mid
# use file: classical_music_midi/chopin/chpn-p4.mid
# use file: classical_music_midi/chopin/chpn_op35_3.mid
# use file: classical_music_midi/chopin/chpn-p22.mid
# use file: classical_music_midi/chopin/chpn_op53.mid
# use file: classical_music_midi/chopin/chpn-p16.mid
# use file: classical_music_midi/chopin/chpn-p24.mid
# use file: classical_music_midi/chopin/chpn-p2.mid
# use file: classical_music_midi/chopin/chpn-p5.mid
# use file: classical_music_midi/chopin/chpn_op7_1.mid
# use file: classical_music_midi/chopin/chpn-p11.mid
# use file: classical_music_midi/chopin/chpn_op25_e3.mid
# use file: classical_music_midi/chopin/chp_op31.mid
# use file: classical_music_midi/chopin/chpn-p19.mid
# use file: classical_music_midi/chopin/chpn-p23.mid
# use file: classical_music_midi/chopin/chpn_op27_2.mid
# use file: classical_music_midi/chopin/chpn_op35_1.mid
# use file: classical_music_midi/chopin/chpn-p20.mid
# ignore file: classical_music_midi/chopin/chpn_op35_2.mid
# use file: classical_music_midi/chopin/chpn-p10.mid
# use file: classical_music_midi/chopin/chpn_op25_e11.mid
# use file: classical_music_midi/chopin/chpn_op25_e12.mid
# use file: classical_music_midi/chopin/chpn_op10_e05.mid
# use file: classical_music_midi/chopin/chpn_op23.mid
# use file: classical_music_midi/chopin/chpn_op10_e12.mid
# use file: classical_music_midi/chopin/chpn_op66.mid
# use file: classical_music_midi/chopin/chpn-p14.mid
# use file: classical_music_midi/chopin/chpn-p1.mid
# use file: classical_music_midi/chopin/chpn-p6.mid
# use file: classical_music_midi/chopin/chpn-p9.mid
# use file: classical_music_midi/chopin/chpn_op33_2.mid
# use file: classical_music_midi/chopin/chpn_op10_e01.mid
# use file: classical_music_midi/chopin/chp_op18.mid
# use file: classical_music_midi/chopin/chpn_op33_4.mid
# use file: classical_music_midi/chopin/chpn-p3.mid
# use file: classical_music_midi/chopin/chpn-p18.mid
# use file: classical_music_midi/chopin/chpn-p7.mid
# use file: classical_music_midi/chopin/chpn-p21.mid
# use file: classical_music_midi/chopin/chpn-p12.mid
# use file: classical_music_midi/chopin/chpn-p8.mid
# use file: classical_music_midi/chopin/chpn_op25_e2.mid
# use file: classical_music_midi/chopin/chpn-p17.mid
# use file: classical_music_midi/chopin/chpn-p15.mid
# use file: classical_music_midi/chopin/chpn_op27_1.mid
# use file: classical_music_midi/chopin/chpn_op7_2.mid
# use file: classical_music_midi/chopin/chpn_op35_4.mid
# use file: classical_music_midi/chopin/chpn-p13.mid
# use file: classical_music_midi/mendelssohn/mendel_op30_5.mid
# use file: classical_music_midi/mendelssohn/mendel_op62_3.mid
# use file: classical_music_midi/mendelssohn/mendel_op62_5.mid
# use file: classical_music_midi/mendelssohn/mendel_op30_4.mid
# use file: classical_music_midi/mendelssohn/mendel_op62_4.mid
# use file: classical_music_midi/mendelssohn/mendel_op19_6.mid
# use file: classical_music_midi/mendelssohn/mendel_op53_5.mid
# use file: classical_music_midi/mendelssohn/mendel_op19_4.mid
# use file: classical_music_midi/mendelssohn/mendel_op19_5.mid
# use file: classical_music_midi/mendelssohn/mendel_op30_3.mid
# use file: classical_music_midi/mendelssohn/mendel_op30_1.mid
# use file: classical_music_midi/mendelssohn/mendel_op30_2.mid
# use file: classical_music_midi/mendelssohn/mendel_op19_3.mid
# use file: classical_music_midi/mendelssohn/mendel_op19_2.mid
# use file: classical_music_midi/mendelssohn/mendel_op19_1.mid
# use file: classical_music_midi/muss/muss_1.mid
# use file: classical_music_midi/muss/muss_2.mid
# use file: classical_music_midi/muss/muss_4.mid
# use file: classical_music_midi/muss/muss_7.mid
# use file: classical_music_midi/muss/muss_6.mid
# use file: classical_music_midi/muss/muss_5.mid
# use file: classical_music_midi/muss/muss_8.mid
# use file: classical_music_midi/muss/muss_3.mid
# use file: classical_music_midi/granados/gra_esp_2.mid
# use file: classical_music_midi/granados/gra_esp_4.mid
# use file: classical_music_midi/granados/gra_esp_3.mid
# use file: classical_music_midi/balakir/islamei.mid
# use file: classical_music_midi/beeth/waldstein_1.mid
# use file: classical_music_midi/beeth/beethoven_opus10_2.mid
# use file: classical_music_midi/beeth/beethoven_hammerklavier_1.mid
# use file: classical_music_midi/beeth/waldstein_2.mid
# use file: classical_music_midi/beeth/waldstein_3.mid
# use file: classical_music_midi/beeth/appass_1.mid
# use file: classical_music_midi/beeth/beethoven_opus10_3.mid
# use file: classical_music_midi/beeth/pathetique_2.mid
# use file: classical_music_midi/beeth/appass_3.mid
# ignore file: classical_music_midi/beeth/mond_2.mid
# use file: classical_music_midi/beeth/beethoven_hammerklavier_3.mid
# use file: classical_music_midi/beeth/beethoven_opus90_2.mid
# use file: classical_music_midi/beeth/elise.mid
# use file: classical_music_midi/beeth/appass_2.mid
# use file: classical_music_midi/beeth/beethoven_opus10_1.mid
# use file: classical_music_midi/beeth/beethoven_les_adieux_3.mid
# use file: classical_music_midi/beeth/pathetique_3.mid
# use file: classical_music_midi/beeth/beethoven_hammerklavier_4.mid
# use file: classical_music_midi/beeth/beethoven_les_adieux_1.mid
# use file: classical_music_midi/beeth/beethoven_hammerklavier_2.mid
# use file: classical_music_midi/beeth/beethoven_opus22_1.mid
# ignore file: classical_music_midi/beeth/mond_1.mid
# use file: classical_music_midi/beeth/beethoven_opus22_3.mid
# use file: classical_music_midi/beeth/beethoven_opus22_4.mid
# use file: classical_music_midi/beeth/beethoven_opus90_1.mid
# use file: classical_music_midi/beeth/pathetique_1.mid
# use file: classical_music_midi/beeth/beethoven_les_adieux_2.mid
# use file: classical_music_midi/beeth/beethoven_opus22_2.mid
# use file: classical_music_midi/beeth/mond_3.mid
# use file: classical_music_midi/grieg/grieg_voeglein.mid
# use file: classical_music_midi/grieg/grieg_wanderer.mid
# use file: classical_music_midi/grieg/grieg_album.mid
# use file: classical_music_midi/grieg/grieg_elfentanz.mid
# use file: classical_music_midi/grieg/grieg_berceuse.mid
# use file: classical_music_midi/grieg/grieg_march.mid
# use file: classical_music_midi/grieg/grieg_spring.mid
# use file: classical_music_midi/grieg/grieg_wedding.mid
# use file: classical_music_midi/grieg/grieg_brooklet.mid
# use file: classical_music_midi/grieg/grieg_once_upon_a_time.mid
# use file: classical_music_midi/grieg/grieg_zwerge.mid
# use file: classical_music_midi/grieg/grieg_kobold.mid
# use file: classical_music_midi/grieg/grieg_walzer.mid
# use file: classical_music_midi/grieg/grieg_halling.mid
# use file: classical_music_midi/grieg/grieg_butterfly.mid
# use file: classical_music_midi/grieg/grieg_waechter.mid
# use file: classical_music_midi/mozart/mz_332_2.mid
# use file: classical_music_midi/mozart/mz_330_3.mid
# use file: classical_music_midi/mozart/mz_330_2.mid
# use file: classical_music_midi/mozart/mz_545_3.mid
# use file: classical_music_midi/mozart/mz_570_3.mid
# use file: classical_music_midi/mozart/mz_330_1.mid
# use file: classical_music_midi/mozart/mz_545_2.mid
# use file: classical_music_midi/mozart/mz_331_1.mid
# use file: classical_music_midi/mozart/mz_570_2.mid
# use file: classical_music_midi/mozart/mz_570_1.mid
# use file: classical_music_midi/mozart/mz_311_3.mid
# use file: classical_music_midi/mozart/mz_331_3.mid
# use file: classical_music_midi/mozart/mz_333_1.mid
# use file: classical_music_midi/mozart/mz_545_1.mid
# use file: classical_music_midi/mozart/mz_333_2.mid
# use file: classical_music_midi/mozart/mz_332_1.mid
# use file: classical_music_midi/mozart/mz_333_3.mid
# use file: classical_music_midi/mozart/mz_311_1.mid
# use file: classical_music_midi/mozart/mz_331_2.mid
# use file: classical_music_midi/mozart/mz_311_2.mid
# use file: classical_music_midi/mozart/mz_332_3.mid
# use file: classical_music_midi/albeniz/alb_esp3.mid
# use file: classical_music_midi/albeniz/alb_se7.mid
# use file: classical_music_midi/albeniz/alb_se6.mid
# use file: classical_music_midi/albeniz/alb_se2.mid
# use file: classical_music_midi/albeniz/alb_se4.mid
# use file: classical_music_midi/albeniz/alb_se5.mid
# use file: classical_music_midi/albeniz/alb_esp6.mid
# use file: classical_music_midi/albeniz/alb_se3.mid
# use file: classical_music_midi/albeniz/alb_esp2.mid
# use file: classical_music_midi/albeniz/alb_esp4.mid
# use file: classical_music_midi/albeniz/alb_se1.mid
# use file: classical_music_midi/albeniz/alb_esp1.mid
# use file: classical_music_midi/albeniz/alb_se8.mid
# use file: classical_music_midi/albeniz/alb_esp5.mid
# use file: classical_music_midi/schubert/schubert_D935_1.mid
# use file: classical_music_midi/schubert/schubert_D850_1.mid
# use file: classical_music_midi/schubert/schub_d760_1.mid
# ignore file: classical_music_midi/schubert/schubert_D935_2.mid
# use file: classical_music_midi/schubert/schub_d960_4.mid
# use file: classical_music_midi/schubert/schuim-4.mid
# use file: classical_music_midi/schubert/schumm-3.mid
# use file: classical_music_midi/schubert/schumm-1.mid
# use file: classical_music_midi/schubert/schumm-4.mid
# use file: classical_music_midi/schubert/schumm-2.mid
# ignore file: classical_music_midi/schubert/schu_143_1.mid
# use file: classical_music_midi/schubert/schub_d960_2.mid
# use file: classical_music_midi/schubert/schu_143_3.mid
# use file: classical_music_midi/schubert/schubert_D850_3.mid
# use file: classical_music_midi/schubert/schubert_D850_2.mid
# use file: classical_music_midi/schubert/schu_143_2.mid
# use file: classical_music_midi/schubert/schuim-2.mid
# use file: classical_music_midi/schubert/schubert_D935_3.mid
# use file: classical_music_midi/schubert/schub_d760_4.mid
# use file: classical_music_midi/schubert/schumm-6.mid
# use file: classical_music_midi/schubert/schubert_D935_4.mid
# use file: classical_music_midi/schubert/schuim-1.mid
# use file: classical_music_midi/schubert/schub_d760_2.mid
# use file: classical_music_midi/schubert/schub_d760_3.mid
# use file: classical_music_midi/schubert/schub_d960_1.mid
# use file: classical_music_midi/schubert/schub_d960_3.mid
# use file: classical_music_midi/schubert/schuim-3.mid
# use file: classical_music_midi/schubert/schubert_D850_4.mid
# use file: classical_music_midi/schubert/schumm-5.mid
# use file: classical_music_midi/bach/bach_846.mid
# use file: classical_music_midi/bach/bach_847.mid
# use file: classical_music_midi/bach/bach_850.mid
# use file: classical_music_midi/debussy/debussy_cc_1.mid
# use file: classical_music_midi/debussy/debussy_cc_2.mid
# use file: classical_music_midi/debussy/debussy_cc_6.mid
# use file: classical_music_midi/debussy/deb_menu.mid
# use file: classical_music_midi/debussy/debussy_cc_3.mid
# use file: classical_music_midi/debussy/DEB_CLAI.MID
# use file: classical_music_midi/debussy/debussy_cc_4.mid
# use file: classical_music_midi/debussy/DEB_PASS.MID
# use file: classical_music_midi/debussy/deb_prel.mid
# use file: classical_music_midi/borodin/bor_ps4.mid
# use file: classical_music_midi/borodin/bor_ps1.mid
# use file: classical_music_midi/borodin/bor_ps3.mid
# use file: classical_music_midi/borodin/bor_ps5.mid
# use file: classical_music_midi/borodin/bor_ps2.mid
# use file: classical_music_midi/borodin/bor_ps7.mid
# use file: classical_music_midi/borodin/bor_ps6.mid
# use file: classical_music_midi/burgm/burg_perlen.mid
# use file: classical_music_midi/burgm/burg_agitato.mid
# use file: classical_music_midi/burgm/burg_gewitter.mid
# use file: classical_music_midi/burgm/burg_spinnerlied.mid
# use file: classical_music_midi/burgm/burg_trennung.mid
# use file: classical_music_midi/burgm/burg_geschwindigkeit.mid
# use file: classical_music_midi/burgm/burg_quelle.mid
# use file: classical_music_midi/burgm/burg_sylphen.mid
# use file: classical_music_midi/burgm/burg_erwachen.mid
# use file: classical_music_midi/brahms/brahms_opus1_2.mid
# use file: classical_music_midi/brahms/br_im5.mid
# use file: classical_music_midi/brahms/brahms_opus1_3.mid
# use file: classical_music_midi/brahms/br_im2.mid
# use file: classical_music_midi/brahms/brahms_opus1_1.mid
# use file: classical_music_midi/brahms/brahms_opus117_2.mid
# use file: classical_music_midi/brahms/BR_IM6.MID
# use file: classical_music_midi/brahms/br_rhap.mid
# use file: classical_music_midi/brahms/brahms_opus1_4.mid
# use file: classical_music_midi/brahms/brahms_opus117_1.mid
# use file: classical_music_midi/liszt/liz_et3.mid
# use file: classical_music_midi/liszt/liz_et6.mid
# use file: classical_music_midi/liszt/liz_et_trans8.mid
# use file: classical_music_midi/liszt/liz_donjuan.mid
# use file: classical_music_midi/liszt/liz_et_trans5.mid
# use file: classical_music_midi/liszt/liz_liebestraum.mid
# use file: classical_music_midi/liszt/liz_et5.mid
# use file: classical_music_midi/liszt/liz_rhap10.mid
# use file: classical_music_midi/liszt/liz_rhap09.mid
# use file: classical_music_midi/liszt/liz_et4.mid
# use file: classical_music_midi/liszt/liz_rhap15.mid
# use file: classical_music_midi/liszt/liz_et_trans4.mid
# use file: classical_music_midi/liszt/liz_et2.mid
# use file: classical_music_midi/liszt/liz_rhap02.mid
# use file: classical_music_midi/liszt/liz_et1.mid
# use file: classical_music_midi/liszt/liz_rhap12.mid

# %%
dataset
# Out:
#                                                     pitches   velocity  \
# haydn/haydn_9_3.mid  0                                 [72]  40.000000
#                      1                         [65, 69, 77]  35.666667
#                      2                                 [72]  40.000000
#                      3                                 [77]  41.000000
#                      4                                 [72]  42.000000
# ...                                                     ...        ...
# liszt/liz_rhap12.mid 3105  [44, 48, 51, 56, 75, 80, 84, 87]  77.375000
#                      3106  [37, 41, 44, 49, 77, 80, 85, 89]  77.375000
#                      3107  [32, 36, 39, 44, 80, 84, 87, 92]  77.375000
#                      3108  [37, 41, 44, 49, 85, 89, 92, 97]  77.375000
#                      3109  [54, 58, 61, 66, 73, 78, 82, 85]  80.875000
#
#                            duration
# haydn/haydn_9_3.mid  0     0.251446
#                      1     0.127866
#                      2     0.127866
#                      3     0.127866
#                      4     0.127866
# ...                             ...
# liszt/liz_rhap12.mid 3105  0.277136
#                      3106  0.277136
#                      3107  0.277137
#                      3108  1.078652
#                      3109  1.136797
#
# [357130 rows x 3 columns]

# %%
dataset.index
# Out:
# MultiIndex([( 'haydn/haydn_9_3.mid',    0),
#             ( 'haydn/haydn_9_3.mid',    1),
#             ( 'haydn/haydn_9_3.mid',    2),
#             ( 'haydn/haydn_9_3.mid',    3),
#             ( 'haydn/haydn_9_3.mid',    4),
#             ( 'haydn/haydn_9_3.mid',    5),
#             ( 'haydn/haydn_9_3.mid',    6),
#             ( 'haydn/haydn_9_3.mid',    7),
#             ( 'haydn/haydn_9_3.mid',    8),
#             ( 'haydn/haydn_9_3.mid',    9),
#             ...
#             ('liszt/liz_rhap12.mid', 3100),
#             ('liszt/liz_rhap12.mid', 3101),
#             ('liszt/liz_rhap12.mid', 3102),
#             ('liszt/liz_rhap12.mid', 3103),
#             ('liszt/liz_rhap12.mid', 3104),
#             ('liszt/liz_rhap12.mid', 3105),
#             ('liszt/liz_rhap12.mid', 3106),
#             ('liszt/liz_rhap12.mid', 3107),
#             ('liszt/liz_rhap12.mid', 3108),
#             ('liszt/liz_rhap12.mid', 3109)],
#            length=357130)

# %% [markdown]
# Save dataset

# %%
dataset.to_pickle('./dataset.pkl')
